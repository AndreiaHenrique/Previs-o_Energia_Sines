# %% [markdown]
# # Previsão de Consumo em Sines — **GRU**
#
# Variante recorrente mais leve (GRU) — mesma arquitectura e features que LSTM, para comparação direta.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")
plt.rcParams["figure.figsize"] = (12, 4.5)

DATA_PATH = os.path.join("data", "dataset_completo_sines.xlsx")
df = pd.read_excel(DATA_PATH)

# Converter datetime corretamente (sem unit='ns' — bug do código original)
df["Data/Hora"] = pd.to_datetime(df["Data/Hora"])
df = df.sort_values("Data/Hora").set_index("Data/Hora")

# Renomear coluna do código postal de Sines
if 7520 in df.columns:
    df = df.rename(columns={7520: "Sines_Consumo"})
df["Sines_Consumo"] = pd.to_numeric(df["Sines_Consumo"], errors="coerce")

print("Período:", df.index.min(), "->", df.index.max())
print("Shape:", df.shape)
df[["Sines_Consumo"]].describe().T
# Out:
# Período: 2023-01-01 00:00:00 -> 2023-09-30 22:00:00
# Shape: (6558, 43)
#                 count          mean           std           min          25%  \
# Sines_Consumo  6558.0  54981.672334  10329.416378  23468.336649  47416.44285
#
#                         50%           75%           max
# Sines_Consumo  55568.033876  62928.197063  79577.898753

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def safe_mape(y_true, y_pred, eps=1.0):
    """MAPE robusto: ignora valores próximos de zero para evitar divisões inválidas."""
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    mask = np.abs(y_true) > eps
    if mask.sum() == 0:
        return np.nan
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

def evaluate(y_true, y_pred, nome="Modelo"):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    mape = safe_mape(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    print(f"\n=== {nome} ===")
    print(f"MAE : {mae:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"R²  : {r2:.3f}")
    return {"MAE": mae, "RMSE": rmse, "MAPE": mape, "R2": r2}

# %%
# Features comuns
cyclical_features = [
    "Hora_sin", "Hora_cos",
    "Dia_Semana_sin", "Dia_Semana_cos",
    "Mes_sin", "Mes_cos",
]
categorical_features = [
    "Fim_de_Semana",
    "Estacao_Inverno", "Estacao_Outono",
    "Estacao_Primavera", "Estacao_Verão",
]
# Lags do target (muito importantes!)
df["lag_1h"]  = df["Sines_Consumo"].shift(1)
df["lag_24h"] = df["Sines_Consumo"].shift(24)

features = cyclical_features + categorical_features + ["lag_1h", "lag_24h"]
features = [f for f in features if f in df.columns]   # tolera variações

df_model = df[features + ["Sines_Consumo"]].dropna()
print("Shape df_model:", df_model.shape)
df_model.head()
# Out:
# Shape df_model: (6534, 14)
#                      Hora_sin  Hora_cos  Dia_Semana_sin  Dia_Semana_cos  \
# Data/Hora
# 2023-01-02 00:00:00  0.000000  1.000000             0.0             1.0
# 2023-01-02 01:00:00  0.258819  0.965926             0.0             1.0
# 2023-01-02 02:00:00  0.500000  0.866025             0.0             1.0
# 2023-01-02 03:00:00  0.707107  0.707107             0.0             1.0
# 2023-01-02 04:00:00  0.866025  0.500000             0.0             1.0
#
#                      Mes_sin  Mes_cos  Fim_de_Semana  Estacao_Inverno  \
# Data/Hora
# 2023-01-02 00:00:00      0.0      1.0              0                1
# 2023-01-02 01:00:00      0.0      1.0              0                1
# 2023-01-02 02:00:00      0.0      1.0              0                1
# 2023-01-02 03:00:00      0.0      1.0              0                1
# 2023-01-02 04:00:00      0.0      1.0              0                1
#
#                      Estacao_Outono  Estacao_Primavera  Estacao_Verão  \
# Data/Hora
# 2023-01-02 00:00:00               0                  0              0
# 2023-01-02 01:00:00               0                  0              0
# 2023-01-02 02:00:00               0                  0              0
# 2023-01-02 03:00:00               0                  0              0
# 2023-01-02 04:00:00               0                  0              0
#
#                            lag_1h       lag_24h  Sines_Consumo
# Data/Hora
# 2023-01-02 00:00:00  47495.585620  45501.800240   46477.362890
# 2023-01-02 01:00:00  46477.362890  45170.849644   45524.832464
# 2023-01-02 02:00:00  45524.832464  44743.436723   45274.757473
# 2023-01-02 03:00:00  45274.757473  44559.972174   44902.097368
# 2023-01-02 04:00:00  44902.097368  44454.468574   44240.505902

# %%
n = len(df_model)
split_idx = int(n * 0.8)
split_ts  = df_model.index[split_idx]
print("Split em:", split_ts)

train_df = df_model.iloc[:split_idx]
test_df  = df_model.iloc[split_idx:]
print("Train:", train_df.shape, " | Test:", test_df.shape)
# Out:
# Split em: 2023-08-07 12:00:00
# Train: (5227, 14)  | Test: (1307, 14)

# %%
from sklearn.preprocessing import MinMaxScaler

X_train_raw = train_df[features].values
y_train_raw = train_df["Sines_Consumo"].values
X_test_raw  = test_df[features].values
y_test_raw  = test_df["Sines_Consumo"].values

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_train_scaled = scaler_X.fit_transform(X_train_raw)
X_test_scaled  = scaler_X.transform(X_test_raw)
y_train_scaled = scaler_y.fit_transform(y_train_raw.reshape(-1, 1))
y_test_scaled  = scaler_y.transform(y_test_raw.reshape(-1, 1))

def create_sequences(X, y, lookback):
    Xs, ys = [], []
    for i in range(lookback, len(X)):
        Xs.append(X[i-lookback:i, :]); ys.append(y[i])
    return np.array(Xs), np.array(ys)

LOOKBACK = 48
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, LOOKBACK)
X_test_seq,  y_test_seq  = create_sequences(X_test_scaled,  y_test_scaled,  LOOKBACK)
print(X_train_seq.shape, X_test_seq.shape)
# Out:
# (5179, 48, 13) (1259, 48, 13)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

tf.random.set_seed(42); np.random.seed(42)

model = Sequential([
    GRU(96, return_sequences=True, kernel_regularizer=l2(1e-4),
        input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    BatchNormalization(),
    Dropout(0.2),

    GRU(48, kernel_regularizer=l2(1e-4)),
    BatchNormalization(),
    Dropout(0.2),

    Dense(1),
])
model.compile(optimizer=Adam(learning_rate=1e-3), loss=Huber(delta=1.0))
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\sofia\Downloads\Energia_Sines\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 48, 96)         │        31,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 96)         │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 48, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 48)             │        21,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            49 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,617 (209.44 KB)
#  Trainable params: 53,329 (208.32 KB)
#  Non-trainable params: 288 (1.12 KB)

# %%
early_stop = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)
reduce_lr  = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=8, min_lr=1e-5, verbose=1)

history = model.fit(
    X_train_seq, y_train_seq,
    validation_split=0.1, epochs=120, batch_size=64,
    callbacks=[early_stop, reduce_lr], verbose=2,
)
# Out:
# Epoch 1/120
# 73/73 - 9s - 117ms/step - loss: 0.3360 - val_loss: 0.0223 - learning_rate: 0.0010
# Epoch 2/120
# 73/73 - 4s - 55ms/step - loss: 0.1842 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 3/120
# 73/73 - 3s - 36ms/step - loss: 0.1269 - val_loss: 0.0321 - learning_rate: 0.0010
# Epoch 4/120
# 73/73 - 2s - 33ms/step - loss: 0.1001 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 5/120
# 73/73 - 3s - 35ms/step - loss: 0.0760 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 6/120
# 73/73 - 3s - 35ms/step - loss: 0.0565 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 7/120
# 73/73 - 3s - 36ms/step - loss: 0.0455 - val_loss: 0.0181 - learning_rate: 0.0010
# Epoch 8/120
# 73/73 - 3s - 34ms/step - loss: 0.0370 - val_loss: 0.0178 - learning_rate: 0.0010
# Epoch 9/120
# 73/73 - 3s - 34ms/step - loss: 0.0299 - val_loss: 0.0131 - learning_rate: 0.0010
# Epoch 10/120
# 73/73 - 3s - 35ms/step - loss: 0.0247 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 11/120
# 73/73 - 3s - 35ms/step - loss: 0.0208 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 12/120
# 73/73 - 3s - 35ms/step - loss: 0.0182 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 13/120
# 73/73 - 3s - 36ms/step - loss: 0.0163 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 14/120
# 73/73 - 2s - 34ms/step - loss: 0.0143 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 15/120
# 73/73 - 3s - 36ms/step - loss: 0.0131 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 16/120
# 73/73 - 3s - 36ms/step - loss: 0.0121 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 17/120
# 73/73 - 3s - 36ms/step - loss: 0.0112 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 18/120
# 73/73 - 2s - 34ms/step - loss: 0.0104 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 19/120
# 73/73 - 3s - 35ms/step - loss: 0.0098 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 20/120
# 73/73 - 3s - 36ms/step - loss: 0.0095 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 21/120
# 73/73 - 3s - 36ms/step - loss: 0.0089 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 22/120
# 73/73 - 3s - 35ms/step - loss: 0.0085 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 23/120
# 73/73 - 3s - 35ms/step - loss: 0.0082 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 24/120
# 73/73 - 2s - 34ms/step - loss: 0.0079 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 25/120
# 73/73 - 3s - 35ms/step - loss: 0.0075 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 26/120
# 73/73 - 3s - 36ms/step - loss: 0.0072 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 27/120
# 73/73 - 3s - 36ms/step - loss: 0.0070 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 28/120
# 73/73 - 3s - 35ms/step - loss: 0.0068 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 29/120
# 73/73 - 2s - 34ms/step - loss: 0.0065 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 30/120
# 73/73 - 3s - 36ms/step - loss: 0.0064 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 31/120
# 73/73 - 3s - 36ms/step - loss: 0.0062 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 32/120
# 73/73 - 3s - 36ms/step - loss: 0.0060 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 33/120
# 73/73 - 3s - 35ms/step - loss: 0.0058 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 34/120
# 73/73 - 3s - 36ms/step - loss: 0.0056 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 35/120
# 73/73 - 3s - 35ms/step - loss: 0.0055 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 36/120
# 73/73 - 3s - 36ms/step - loss: 0.0054 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 37/120
# 73/73 - 3s - 36ms/step - loss: 0.0052 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 38/120
# 73/73 - 3s - 37ms/step - loss: 0.0050 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 39/120
# 73/73 - 3s - 36ms/step - loss: 0.0049 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 40/120
# 73/73 - 2s - 33ms/step - loss: 0.0048 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 41/120
# 73/73 - 2s - 31ms/step - loss: 0.0046 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 42/120
# 73/73 - 2s - 33ms/step - loss: 0.0045 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 43/120
# 73/73 - 2s - 30ms/step - loss: 0.0044 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 44/120
# 73/73 - 2s - 29ms/step - loss: 0.0044 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 45/120
# 73/73 - 2s - 29ms/step - loss: 0.0042 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 46/120
# 73/73 - 2s - 31ms/step - loss: 0.0042 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 47/120
# 73/73 - 2s - 32ms/step - loss: 0.0040 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 48/120
# 73/73 - 2s - 32ms/step - loss: 0.0039 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 49/120
# 73/73 - 2s - 30ms/step - loss: 0.0039 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 50/120
# 73/73 - 2s - 33ms/step - loss: 0.0038 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 51/120
# 73/73 - 3s - 35ms/step - loss: 0.0037 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 52/120
# 73/73 - 3s - 35ms/step - loss: 0.0036 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 53/120
# 73/73 - 2s - 34ms/step - loss: 0.0036 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 54/120
# 73/73 - 2s - 32ms/step - loss: 0.0035 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 55/120
# 73/73 - 3s - 34ms/step - loss: 0.0034 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 56/120
# 73/73 - 2s - 30ms/step - loss: 0.0033 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 57/120
# 73/73 - 2s - 32ms/step - loss: 0.0033 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 58/120
# 73/73 - 2s - 33ms/step - loss: 0.0032 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 59/120
# 73/73 - 2s - 32ms/step - loss: 0.0031 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 60/120
# 73/73 - 2s - 30ms/step - loss: 0.0030 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 61/120
# 73/73 - 2s - 31ms/step - loss: 0.0030 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 62/120
# 73/73 - 2s - 30ms/step - loss: 0.0029 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 63/120
# 73/73 - 2s - 31ms/step - loss: 0.0028 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 64/120
# 73/73 - 2s - 30ms/step - loss: 0.0028 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 65/120
# 73/73 - 2s - 28ms/step - loss: 0.0027 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 66/120
# 73/73 - 2s - 29ms/step - loss: 0.0027 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 67/120
# 73/73 - 2s - 29ms/step - loss: 0.0026 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 68/120
# 73/73 - 2s - 29ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 69/120
# 73/73 - 2s - 30ms/step - loss: 0.0025 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 70/120
# 73/73 - 2s - 31ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 71/120
# 73/73 - 2s - 30ms/step - loss: 0.0024 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 72/120
# 73/73 - 2s - 29ms/step - loss: 0.0024 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 73/120
# 73/73 - 2s - 27ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 74/120
# 73/73 - 2s - 28ms/step - loss: 0.0023 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 75/120
# 73/73 - 2s - 29ms/step - loss: 0.0022 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 76/120
# 73/73 - 2s - 29ms/step - loss: 0.0022 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 77/120
# 73/73 - 2s - 28ms/step - loss: 0.0022 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 78/120
# 73/73 - 2s - 28ms/step - loss: 0.0021 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 79/120
# 73/73 - 2s - 28ms/step - loss: 0.0021 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 80/120
# 73/73 - 2s - 29ms/step - loss: 0.0020 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 81/120
# 73/73 - 2s - 28ms/step - loss: 0.0020 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 82/120
# 73/73 - 2s - 28ms/step - loss: 0.0020 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 83/120
# 73/73 - 2s - 28ms/step - loss: 0.0019 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 84/120
# 73/73 - 2s - 28ms/step - loss: 0.0019 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 85/120
# 73/73 - 2s - 28ms/step - loss: 0.0019 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 86/120
# 73/73 - 2s - 28ms/step - loss: 0.0018 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 87/120
# 73/73 - 2s - 28ms/step - loss: 0.0018 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 88/120
# 73/73 - 2s - 28ms/step - loss: 0.0018 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 89/120
# 73/73 - 2s - 28ms/step - loss: 0.0018 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 90/120
# 73/73 - 2s - 29ms/step - loss: 0.0018 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 91/120
# 73/73 - 2s - 28ms/step - loss: 0.0017 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 92/120
# 73/73 - 2s - 28ms/step - loss: 0.0017 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 93/120
# 73/73 - 2s - 28ms/step - loss: 0.0017 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 94/120
# 73/73 - 2s - 28ms/step - loss: 0.0017 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 95/120
# 73/73 - 2s - 28ms/step - loss: 0.0017 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 96/120
# 73/73 - 2s - 28ms/step - loss: 0.0016 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 97/120
# 73/73 - 2s - 28ms/step - loss: 0.0016 - val_loss: 9.4589e-04 - learning_rate: 0.0010
# Epoch 98/120
# 73/73 - 2s - 29ms/step - loss: 0.0016 - val_loss: 9.4864e-04 - learning_rate: 0.0010
# Epoch 99/120
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 73/73 - 2s - 28ms/step - loss: 0.0016 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 100/120
# 73/73 - 2s - 28ms/step - loss: 0.0015 - val_loss: 9.2623e-04 - learning_rate: 5.0000e-04
# Epoch 101/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.5900e-04 - learning_rate: 5.0000e-04
# Epoch 102/120
# 73/73 - 2s - 28ms/step - loss: 0.0015 - val_loss: 8.2804e-04 - learning_rate: 5.0000e-04
# Epoch 103/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 9.0768e-04 - learning_rate: 5.0000e-04
# Epoch 104/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.1903e-04 - learning_rate: 5.0000e-04
# Epoch 105/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 7.8987e-04 - learning_rate: 5.0000e-04
# Epoch 106/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.7142e-04 - learning_rate: 5.0000e-04
# Epoch 107/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.0433e-04 - learning_rate: 5.0000e-04
# Epoch 108/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.8339e-04 - learning_rate: 5.0000e-04
# Epoch 109/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 7.7013e-04 - learning_rate: 5.0000e-04
# Epoch 110/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 8.3346e-04 - learning_rate: 5.0000e-04
# Epoch 111/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 112/120
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 7.6863e-04 - learning_rate: 5.0000e-04
# Epoch 113/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 7.7535e-04 - learning_rate: 2.5000e-04
# Epoch 114/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 9.3726e-04 - learning_rate: 2.5000e-04
# Epoch 115/120
# 73/73 - 2s - 29ms/step - loss: 0.0013 - val_loss: 9.1844e-04 - learning_rate: 2.5000e-04
# Epoch 116/120
# 73/73 - 2s - 28ms/step - loss: 0.0013 - val_loss: 9.9278e-04 - learning_rate: 2.5000e-04
# Epoch 117/120
# 73/73 - 2s - 28ms/step - loss: 0.0013 - val_loss: 8.5837e-04 - learning_rate: 2.5000e-04
# Epoch 118/120
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 9.6411e-04 - learning_rate: 2.5000e-04
# Epoch 119/120
# 73/73 - 2s - 28ms/step - loss: 0.0013 - val_loss: 8.6213e-04 - learning_rate: 2.5000e-04
# Epoch 120/120
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 73/73 - 2s - 28ms/step - loss: 0.0014 - val_loss: 7.5950e-04 - learning_rate: 2.5000e-04

# %%
plt.figure(figsize=(10, 4.5))
plt.plot(history.history["loss"], label="Treino")
plt.plot(history.history["val_loss"], label="Validação")
plt.title("Evolução da Loss — GRU")
plt.xlabel("Época"); plt.ylabel("Loss"); plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %%
y_pred_scaled = model.predict(X_test_seq, verbose=0)
y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()
y_real = y_test_raw[LOOKBACK:]

metrics_gru = evaluate(y_real, y_pred, nome="GRU")
# Out:
# === GRU ===
# MAE : 1239.294
# RMSE: 1822.036
# MAPE: 2.51%
# R²  : 0.977

# %%
idx = test_df.index[LOOKBACK:]
fig, axes = plt.subplots(2, 1, figsize=(14, 8))
axes[0].plot(idx, y_real, label="Real", linewidth=1)
axes[0].plot(idx, y_pred, label="Previsto", linewidth=1, alpha=0.85)
axes[0].set_title("GRU — período de teste completo")
axes[0].set_ylabel("Consumo (kWh)"); axes[0].legend(); axes[0].grid(True, alpha=0.3)

zoom = 200
axes[1].plot(idx[:zoom], y_real[:zoom], label="Real", linewidth=1.4)
axes[1].plot(idx[:zoom], y_pred[:zoom], label="Previsto", linewidth=1.4)
axes[1].set_title(f"GRU — zoom primeiros {zoom} pontos")
axes[1].set_xlabel("Tempo"); axes[1].set_ylabel("Consumo (kWh)")
axes[1].legend(); axes[1].grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %%
os.makedirs("results", exist_ok=True)
pd.DataFrame([metrics_gru], index=["GRU"]).to_csv("results/metrics_gru.csv")
print("Resultados guardados em results/metrics_gru.csv")
# Out:
# Resultados guardados em results/metrics_gru.csv
